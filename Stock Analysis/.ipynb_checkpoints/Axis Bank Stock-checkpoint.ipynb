# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dt
import quandl
# %matplotlib inline
from matplotlib.finance import candlestick_ohlc
import matplotlib.dates as mdates
from matplotlib import style

style.use('ggplot')
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: The finance module has been deprecated in mpl 2.0 and will be removed in mpl 2.2. Please use the module mpl_finance instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
axis_data = quandl.get('NSE/AXISBANK', start_date = '2015-01-01')

# %%
axis_data.index
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-05', '2015-01-06',
#                '2015-01-07', '2015-01-08', '2015-01-09', '2015-01-12',
#                '2015-01-13', '2015-01-14',
#                ...
#                '2018-02-15', '2018-02-16', '2018-02-19', '2018-02-20',
#                '2018-02-21', '2018-02-22', '2018-02-23', '2018-02-26',
#                '2018-02-27', '2018-02-28'],
#               dtype='datetime64[ns]', name='Date', length=784, freq=None)

# %%
axis_data.tail()
# Out:
#              Open    High     Low   Last   Close  Total Trade Quantity  \
# Date
# 2018-02-22  533.0  533.75  527.50  529.2  530.25             7808359.0
# 2018-02-23  527.0  538.90  525.55  537.5  536.65             3888629.0
# 2018-02-26  541.1  554.40  539.00  550.0  552.30             5297794.0
# 2018-02-27  551.6  551.60  536.15  539.5  538.40             4136383.0
# 2018-02-28  534.0  536.50  520.00  526.7  528.75             6626661.0
#
#             Turnover (Lacs)
# Date
# 2018-02-22         41413.58
# 2018-02-23         20757.56
# 2018-02-26         29036.44
# 2018-02-27         22462.84
# 2018-02-28         34996.01

# %%
plt.figure(figsize = (10,10))

ax1 = plt.subplot2grid((10,10),(0,0), rowspan = 7,colspan =10)
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('CLOSING PRICE')

ax2 = plt.subplot2grid((10,10),(7,0),rowspan = 3, colspan = 10)
plt.xlabel('Time')
plt.ylabel('Quantity Traded')
plt.title('VOLUME')

ax1.plot(axis_data['Close'], linestyle = '--',color = 'r', alpha = 0.6)
ax2.plot(axis_data['Total Trade Quantity'])

ax1.grid(True)
ax2.grid(True)


plt.tight_layout()
plt.show()

# %%
ohlc = axis_data.loc['2018'][['Open','High','Low','Close']]
ohlc.reset_index(inplace = True)
ohlc['Date'] = ohlc['Date'].map(mdates.date2num)


fig = plt.figure(figsize = (15,15))
ax1 = fig.subplots()


for label in ax1.get_xticklabels():
    label.set_rotation(45)

ax1.xaxis_date()
ax1.grid(True)
candlestick_ohlc(ax1,ohlc.values)

plt.title('CANDLESTICK OHLC')
plt.tight_layout()
plt.show()

# %%
axis_data.describe()
# Out:
#              Open        High         Low        Last       Close  \
# count  784.000000  784.000000  784.000000  784.000000  784.000000
# mean   513.503125  519.821492  506.379974  512.905676  512.880931
# std     51.775239   52.284271   51.025803   51.687789   51.649529
# min    372.250000  383.350000  366.750000  372.850000  373.200000
# 25%    483.012500  488.162500  474.387500  480.950000  481.900000
# 50%    513.450000  518.975000  506.750000  512.975000  513.050000
# 75%    553.000000  558.900000  545.362500  552.025000  551.837500
# max    650.900000  654.900000  628.700000  650.000000  647.550000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          7.840000e+02       784.000000
# mean           8.355548e+06     42339.835510
# std            6.831349e+06     35271.585048
# min            9.377010e+05      4581.790000
# 25%            5.256876e+06     26874.522500
# 50%            6.981755e+06     35910.460000
# 75%            9.706553e+06     48117.702500
# max            1.205419e+08    717955.040000

# %%
moving_averages = [21,42,100]

for num in moving_averages:
    def moving(num):
        return(axis_data['Close'].rolling(num).mean())
    axis_data['MA {}'.format(num)] = moving(num)
    
axis_data['Volatility'] = axis_data['Close'].rolling(21).std()

# %%
axis_data.head(3)
# Out:
#               Open   High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2015-01-01  502.65  504.0  499.05  503.00  503.05             1351985.0
# 2015-01-02  503.20  516.9  501.70  514.55  514.30             3852825.0
# 2015-01-05  516.90  520.4  515.10  516.50  517.55             2561430.0
#
#             Turnover (Lacs)  MA 21  MA 42  MA 100  Volatility
# Date
# 2015-01-01          6779.90    NaN    NaN     NaN         NaN
# 2015-01-02         19738.87    NaN    NaN     NaN         NaN
# 2015-01-05         13262.09    NaN    NaN     NaN         NaN

# %%
axis_data.loc[:,['MA 21', 'MA 42','MA 100']].plot(figsize  =(15,10))
axis_data['Close'].plot(alpha = 0.2, figsize = (15,10),legend = True, color = 'g')
plt.title('MOVING AVERAGE')
# Out:
# Text(0.5,1,'MOVING AVERAGE')

# %%
axis_data['Volatility'].plot(figsize = (10,10), legend = True, grid = True)
plt.title('VOLATILITY')
# Out:
# Text(0.5,1,'VOLATILITY')

# %%
axis_data['Pct_change'] = axis_data['Close'].pct_change()

# %%
axis_data.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2015-01-01  502.65  504.00  499.05  503.00  503.05             1351985.0
# 2015-01-02  503.20  516.90  501.70  514.55  514.30             3852825.0
# 2015-01-05  516.90  520.40  515.10  516.50  517.55             2561430.0
# 2015-01-06  513.55  513.55  496.75  498.50  499.05             5284530.0
# 2015-01-07  498.80  505.35  494.50  501.00  498.65             4245189.0
#
#             Turnover (Lacs)  MA 21  MA 42  MA 100  Volatility  Pct_change
# Date
# 2015-01-01          6779.90    NaN    NaN     NaN         NaN         NaN
# 2015-01-02         19738.87    NaN    NaN     NaN         NaN    0.022364
# 2015-01-05         13262.09    NaN    NaN     NaN         NaN    0.006319
# 2015-01-06         26584.93    NaN    NaN     NaN         NaN   -0.035745
# 2015-01-07         21212.71    NaN    NaN     NaN         NaN   -0.000802

# %%
axis_data['Pct_change'].describe()
# Out:
# count    783.000000
# mean       0.000253
# std        0.019486
# min       -0.094807
# 25%       -0.010290
# 50%       -0.000089
# 75%        0.009751
# max        0.080888
# Name: Pct_change, dtype: float64

# %%
ax1 = plt.subplot2grid((2,2),(0,0), rowspan = 1,colspan = 2)
axis_data['Pct_change'].plot(figsize = (15,10),linestyle = '--', grid = True)
plt.title('Daily Pct Change')

ax2 = plt.subplot2grid((2,2),(1,0),rowspan = 1,colspan = 1)
axis_data['Pct_change'].hist(figsize = (15,10),bins = 30)
plt.ylabel('Frequency')
plt.title('Histogram')

ax3 = plt.subplot2grid((2,2),(1,1),rowspan = 1,colspan = 1)
axis_data['Pct_change'].plot(figsize = (15,10),kind = 'kde',grid = True)
plt.title('KDE')

plt.tight_layout()

# %%
axis_data['Cum_return'] = (1 + axis_data['Pct_change']).cumprod()

# %%
axis_data.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2015-01-01  502.65  504.00  499.05  503.00  503.05             1351985.0
# 2015-01-02  503.20  516.90  501.70  514.55  514.30             3852825.0
# 2015-01-05  516.90  520.40  515.10  516.50  517.55             2561430.0
# 2015-01-06  513.55  513.55  496.75  498.50  499.05             5284530.0
# 2015-01-07  498.80  505.35  494.50  501.00  498.65             4245189.0
#
#             Turnover (Lacs)  MA 21  MA 42  MA 100  Volatility  Pct_change  \
# Date
# 2015-01-01          6779.90    NaN    NaN     NaN         NaN         NaN
# 2015-01-02         19738.87    NaN    NaN     NaN         NaN    0.022364
# 2015-01-05         13262.09    NaN    NaN     NaN         NaN    0.006319
# 2015-01-06         26584.93    NaN    NaN     NaN         NaN   -0.035745
# 2015-01-07         21212.71    NaN    NaN     NaN         NaN   -0.000802
#
#             Cum_return
# Date
# 2015-01-01         NaN
# 2015-01-02    1.022364
# 2015-01-05    1.028824
# 2015-01-06    0.992049
# 2015-01-07    0.991253

# %%
axis_data['Cum_return'].plot(figsize = (10,10),grid = True,legend = True)
plt.title('CUMMULATIVE RETURN')
# Out:
# Text(0.5,1,'CUMMULATIVE RETURN')

# %%
del axis_data['Volatility']

# %%
del axis_data['Pct_change']

# %%
axis_data.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2015-01-01  502.65  504.00  499.05  503.00  503.05             1351985.0
# 2015-01-02  503.20  516.90  501.70  514.55  514.30             3852825.0
# 2015-01-05  516.90  520.40  515.10  516.50  517.55             2561430.0
# 2015-01-06  513.55  513.55  496.75  498.50  499.05             5284530.0
# 2015-01-07  498.80  505.35  494.50  501.00  498.65             4245189.0
#
#             Turnover (Lacs)  MA 21  MA 42  MA 100  Cum_return
# Date
# 2015-01-01          6779.90    NaN    NaN     NaN         NaN
# 2015-01-02         19738.87    NaN    NaN     NaN    1.022364
# 2015-01-05         13262.09    NaN    NaN     NaN    1.028824
# 2015-01-06         26584.93    NaN    NaN     NaN    0.992049
# 2015-01-07         21212.71    NaN    NaN     NaN    0.991253

# %%
axis_data.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2015-01-01  502.65  504.00  499.05  503.00  503.05             1351985.0
# 2015-01-02  503.20  516.90  501.70  514.55  514.30             3852825.0
# 2015-01-05  516.90  520.40  515.10  516.50  517.55             2561430.0
# 2015-01-06  513.55  513.55  496.75  498.50  499.05             5284530.0
# 2015-01-07  498.80  505.35  494.50  501.00  498.65             4245189.0
#
#             Turnover (Lacs)  MA 21  MA 42  MA 100  Cum_return
# Date
# 2015-01-01          6779.90    NaN    NaN     NaN         NaN
# 2015-01-02         19738.87    NaN    NaN     NaN    1.022364
# 2015-01-05         13262.09    NaN    NaN     NaN    1.028824
# 2015-01-06         26584.93    NaN    NaN     NaN    0.992049
# 2015-01-07         21212.71    NaN    NaN     NaN    0.991253

# %%
axis_data['21d-42d'] = axis_data['MA 21'] - axis_data['MA 42']

# %%
axis_data
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2015-01-01  502.65  504.00  499.05  503.00  503.05             1351985.0
# 2015-01-02  503.20  516.90  501.70  514.55  514.30             3852825.0
# 2015-01-05  516.90  520.40  515.10  516.50  517.55             2561430.0
# 2015-01-06  513.55  513.55  496.75  498.50  499.05             5284530.0
# 2015-01-07  498.80  505.35  494.50  501.00  498.65             4245189.0
# 2018-02-07  14.676190       1     0.0
# 2018-02-08  14.208333       1     0.0
# 2018-02-09  13.661905       1     0.0
# 2018-02-12  13.311905       1     0.0
# 2018-02-14  12.584524       1     0.0
# 2018-02-15  11.728571       1     0.0
# 2018-02-16  10.761905       1     0.0
# 2018-02-19   8.828571       1     0.0
# 2018-02-20   6.822619       1     0.0
# 2018-02-21   4.675000       1     0.0
# 2018-02-22   1.248810       1     0.0
# 2018-02-23  -2.321429      -1    -1.0
# 2018-02-26  -4.907143      -1     0.0
# 2018-02-27  -8.221429      -1     0.0
# 2018-02-28 -11.447619      -1     0.0
#
# [784 rows x 14 columns]

# %%
axis_data['Regime'] =np.where(axis_data['21d-42d']>0,1,0)

axis_data['Regime'] = np.where(axis_data['21d-42d']<0,-1,axis_data['Regime'])

# %%
axis_data.tail()
# Out:
#              Open    High     Low   Last   Close  Total Trade Quantity  \
# Date
# 2018-02-22  533.0  533.75  527.50  529.2  530.25             7808359.0
# 2018-02-23  527.0  538.90  525.55  537.5  536.65             3888629.0
# 2018-02-26  541.1  554.40  539.00  550.0  552.30             5297794.0
# 2018-02-27  551.6  551.60  536.15  539.5  538.40             4136383.0
# 2018-02-28  534.0  536.50  520.00  526.7  528.75             6626661.0
#
#             Turnover (Lacs)       MA 21       MA 42    MA 100  Cum_return  \
# Date
# 2018-02-22         41413.58  568.476190  567.227381  543.1585    1.054070
# 2018-02-23         20757.56  564.502381  566.823810  543.4335    1.066793
# 2018-02-26         29036.44  561.852381  566.759524  543.8600    1.097903
# 2018-02-27         22462.84  558.152381  566.373810  544.1845    1.070271
# 2018-02-28         34996.01  554.495238  565.942857  544.4600    1.051088
#
#               21d-42d  Regime
# Date
# 2018-02-22   1.248810       1
# 2018-02-23  -2.321429      -1
# 2018-02-26  -4.907143      -1
# 2018-02-27  -8.221429      -1
# 2018-02-28 -11.447619      -1

# %%
axis_data['Regime'].plot(ylim = (-2,2),figsize = (10,10))

# %%
axis_data['Regime'].value_counts()
# Out:
#  1    439
# -1    304
#  0     41
# Name: Regime, dtype: int64

# %%
axis_data.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2015-01-01  502.65  504.00  499.05  503.00  503.05             1351985.0
# 2015-01-02  503.20  516.90  501.70  514.55  514.30             3852825.0
# 2015-01-05  516.90  520.40  515.10  516.50  517.55             2561430.0
# 2015-01-06  513.55  513.55  496.75  498.50  499.05             5284530.0
# 2015-01-07  498.80  505.35  494.50  501.00  498.65             4245189.0
#
#             Turnover (Lacs)  MA 21  MA 42  MA 100  Cum_return  21d-42d  \
# Date
# 2015-01-01          6779.90    NaN    NaN     NaN         NaN      NaN
# 2015-01-02         19738.87    NaN    NaN     NaN    1.022364      NaN
# 2015-01-05         13262.09    NaN    NaN     NaN    1.028824      NaN
# 2015-01-06         26584.93    NaN    NaN     NaN    0.992049      NaN
# 2015-01-07         21212.71    NaN    NaN     NaN    0.991253      NaN
#
#             Regime  Signal
# Date
# 2015-01-01       0     NaN
# 2015-01-02       0     0.0
# 2015-01-05       0     0.0
# 2015-01-06       0     0.0
# 2015-01-07       0     0.0

# %%
axis_data['Signal'] = np.sign(axis_data['Regime'] - axis_data['Regime'].shift(1))
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sign
#   """Entry point for launching an IPython kernel.

# %%
axis_data['Signal'].value_counts()
# Out:
#  0.0    761
# -1.0     11
#  1.0     11
# Name: Signal, dtype: int64

# %%
axis_data['Signal'].plot(figsize = (10,10),ylim = (-2,2))

# %%
axis_data['Close'][axis_data['Signal'] == 1]
# Out:
# Date
# 2015-03-02    647.55
# 2015-05-26    564.25
# 2015-07-02    584.00
# 2015-10-16    504.65
# 2016-03-11    412.80
# 2017-01-25    463.55
# 2017-05-04    518.85
# 2017-06-12    507.50
# 2017-07-20    540.00
# 2017-09-22    505.30
# 2017-11-17    542.40
# Name: Close, dtype: float64

# %%
axis_data['Close'][axis_data['Signal'] == -1]
# Out:
# Date
# 2015-04-06    569.05
# 2015-06-29    562.70
# 2015-08-17    561.40
# 2015-11-05    463.80
# 2016-10-05    535.70
# 2017-04-12    506.00
# 2017-06-08    515.75
# 2017-07-19    520.20
# 2017-08-21    494.80
# 2017-10-23    449.95
# 2018-02-23    536.65
# Name: Close, dtype: float64

# %%
axis_signals = pd.concat([pd.DataFrame({'Price': axis_data['Close'][axis_data['Signal']==1],
                            'Regime': axis_data['Regime'][axis_data['Signal']==1],
                            'Signal': 'Buy'
                            }),
                         pd.DataFrame({'Price': axis_data['Close'][axis_data['Signal']==-1],
                            'Regime': axis_data['Regime'][axis_data['Signal']==-1],
                            'Signal': 'Sell'
                            })
                         
                         ])

# %%
axis_signals.sort_index(inplace = True)
axis_signals
# Out:
#              Price  Regime Signal
# Date
# 2015-03-02  647.55       1    Buy
# 2015-04-06  569.05      -1   Sell
# 2015-05-26  564.25       1    Buy
# 2015-06-29  562.70      -1   Sell
# 2015-07-02  584.00       1    Buy
# 2015-08-17  561.40      -1   Sell
# 2015-10-16  504.65       1    Buy
# 2015-11-05  463.80      -1   Sell
# 2016-03-11  412.80       1    Buy
# 2016-10-05  535.70      -1   Sell
# 2017-01-25  463.55       1    Buy
# 2017-04-12  506.00      -1   Sell
# 2017-05-04  518.85       1    Buy
# 2017-06-08  515.75      -1   Sell
# 2017-06-12  507.50       1    Buy
# 2017-07-19  520.20      -1   Sell
# 2017-07-20  540.00       1    Buy
# 2017-08-21  494.80      -1   Sell
# 2017-09-22  505.30       1    Buy
# 2017-10-23  449.95      -1   Sell
# 2017-11-17  542.40       1    Buy
# 2018-02-23  536.65      -1   Sell

# %%
price = axis_signals['Price'][axis_signals['Signal'] == 'Buy']

# %%
price
# Out:
# Date
# 2015-03-02    647.55
# 2015-05-26    564.25
# 2015-07-02    584.00
# 2015-10-16    504.65
# 2016-03-11    412.80
# 2017-01-25    463.55
# 2017-05-04    518.85
# 2017-06-12    507.50
# 2017-07-20    540.00
# 2017-09-22    505.30
# 2017-11-17    542.40
# Name: Price, dtype: float64

# %%
axis_signals['dummy profit'] = axis_signals['Price']-axis_signals['Price'].shift(1)

# %%
profit = pd.eries(axis_signals['dummy profit'][axis_signals['Signal'] == 'Sell'].values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-5828c42b495a> in <module>()
# ----> 1 profit = pd.series(axis_signals['dummy profit'][axis_signals['Signal'] == 'Sell'].values)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
profit
# Out:
# array([ -78.5 ,   -1.55,  -22.6 ,  -40.85,  122.9 ,   42.45,   -3.1 ,
#          12.7 ,  -45.2 ,  -55.35,   -5.75])
