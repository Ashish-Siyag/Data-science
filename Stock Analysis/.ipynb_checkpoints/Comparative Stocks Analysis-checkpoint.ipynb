# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import quandl
from datetime import datetime as dt
import datetime
import seaborn as sns
# %matplotlib inline

# %%
tickers = ['NSE/ICICIBANK','NSE/SBIN','NSE/AXISBANK']

# %%
def get_data(ticker,start,end):
    def data(ticker):
        return quandl.get(ticker, authtoken="Gw-UU-RZKx9mWqJy-gsP", start_date = start, end_date = end)
    datas = map(data, tickers)
    return pd.concat(datas, keys = tickers,names = ['ticker','Date'])

# %%
data = get_data(tickers, '2006-10-01','')

# %%
data.head(3)
# Out:
#                            Open   High    Low    Last   Close  \
# ticker        Date
# NSE/ICICIBANK 2006-10-03  700.0  708.0  691.5  692.10  697.75
#               2006-10-04  675.6  698.0  675.6  693.55  695.05
#               2006-10-05  696.0  709.8  696.0  706.00  705.85
#
#                           Total Trade Quantity  Turnover (Lacs)
# ticker        Date
# NSE/ICICIBANK 2006-10-03              760505.0          5330.94
#               2006-10-04              711991.0          4938.19
#               2006-10-05              939896.0          6636.14

# %%
data.tail(3)
# Out:
#                           Open    High     Low   Last   Close  \
# ticker       Date
# NSE/AXISBANK 2018-02-21  534.0  538.50  524.40  536.0  535.80
#              2018-02-22  533.0  533.75  527.50  529.2  530.25
#              2018-02-23  527.0  538.90  525.55  537.5  536.65
#
#                          Total Trade Quantity  Turnover (Lacs)
# ticker       Date
# NSE/AXISBANK 2018-02-21             4638382.0         24646.81
#              2018-02-22             7808359.0         41413.58
#              2018-02-23             3888629.0         20757.56

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
data.loc['NSE/SBIN']['Close'].plot(figsize = (10,10))
plt.show()

# %%
all_data = get_data(tickers, '2015-01-01','')

# %%
sample = all_data.sample(5)
print(sample)
# Out:
#                            Open   High     Low    Last   Close  \
# ticker        Date
# NSE/SBIN      2017-09-29  254.7  255.5  253.05  254.25  253.85
# NSE/ICICIBANK 2017-02-17  279.7  286.1  275.85  284.60  283.00
# NSE/AXISBANK  2016-02-18  410.2  412.1  391.60  397.20  398.05
# NSE/ICICIBANK 2017-01-02  256.3  256.3  248.10  252.25  251.95
# NSE/AXISBANK  2015-01-23  571.0  577.4  560.30  566.00  565.15
#
#                           Total Trade Quantity  Turnover (Lacs)
# ticker        Date
# NSE/SBIN      2017-09-29            10073641.0         25601.75
# NSE/ICICIBANK 2017-02-17            25905766.0         72917.14
# NSE/AXISBANK  2016-02-18            12069460.0         48572.87
# NSE/ICICIBANK 2017-01-02             9458500.0         23784.17
# NSE/AXISBANK  2015-01-23             4975114.0         28229.43

# %%
close_dat = pd.DataFrame({'AXISBANK' : all_data.loc['NSE/AXISBANK']['Close'], 
                          'ICICIBANK' : all_data.loc['NSE/ICICIBANK']['Close']})

# %%
close_dat.head(3)
# Out:
#             AXISBANK  ICICIBANK
# Date
# 2015-01-01    503.05     352.30
# 2015-01-02    514.30     362.30
# 2015-01-05    517.55     363.05

# %%
close_data = all_data['Close'].reset_index().pivot('Date','ticker','Close')

# %%
close_data.head(3)
# Out:
# ticker      NSE/AXISBANK  NSE/ICICIBANK  NSE/SBIN
# Date
# 2015-01-01        503.05         352.30    314.00
# 2015-01-02        514.30         362.30    315.25
# 2015-01-05        517.55         363.05    312.75

# %%
close_data.plot(secondary_y = ['NSE/AXISBANK'],figsize = (15,10),grid = True)
plt.show()

# %%
pct_change = close_data.pct_change()
quaterly_change = pct_change.resample('4M').mean()
yearly_change = pct_change.resample('12M').mean()

# %%
print('daily_change')
pct_change.describe()
# Out:
# daily_change
# ticker  NSE/AXISBANK  NSE/ICICIBANK    NSE/SBIN
# count     780.000000     780.000000  780.000000
# mean        0.000272       0.000094    0.000075
# std         0.019464       0.020395    0.022312
# min        -0.094807      -0.089545   -0.082617
# 25%        -0.010149      -0.010893   -0.011394
# 50%         0.000041      -0.001023   -0.000353
# 75%         0.009724       0.010372    0.010410
# max         0.080888       0.146877    0.276872

# %%
print('quaterly_change')
quaterly_change.describe()
# Out:
# quaterly_change
# ticker  NSE/AXISBANK  NSE/ICICIBANK   NSE/SBIN
# count      11.000000      11.000000  11.000000
# mean        0.000346      -0.000215  -0.000541
# std         0.003571       0.002485   0.003085
# min        -0.006141      -0.005451  -0.007688
# 25%        -0.001647      -0.001738  -0.001512
# 50%         0.000220       0.000547  -0.000560
# 75%         0.001681       0.001300   0.001704
# max         0.008049       0.003128   0.003061

# %%
print('yearly_change')
yearly_change.describe()
# Out:
# yearly_change
# ticker  NSE/AXISBANK  NSE/ICICIBANK  NSE/SBIN
# count       5.000000       5.000000  5.000000
# mean        0.000500      -0.000692 -0.001497
# std         0.005112       0.002937  0.003749
# min        -0.006141      -0.005451 -0.007688
# 25%        -0.001234      -0.001626 -0.001984
# 50%         0.000719       0.000879 -0.000560
# 75%         0.001109       0.001263  0.000993
# max         0.008049       0.001477  0.001756

# %%
pct_change.hist(bins = 20,figsize = (10,10), grid = True)
plt.show()

# %%
print('daily_pct_change')
pd.plotting.scatter_matrix(pct_change, diagonal = 'kde',figsize = (10,10))
plt.show()
# Out:
# daily_pct_change

# %%
cum_return = (1+pct_change).cumprod()

# %%
cum_return.plot(figsize = (20,10),grid = True)
plt.show()

# %%
cum_return.resample('4M').mean().plot(figsize = (20,10),grid = True)
plt.show()

# %%
print('daily_cum_return')
display(pd.plotting.scatter_matrix(cum_return,figsize = (10,10)))
# Out:
# daily_cum_return
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021E00996F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021E7FCCE710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021E000B4940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021E00931588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021E00C609B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021E00C609E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021E00882240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021E008BA710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021E008F4630>]], dtype=object)

# %%
volatility = pct_change.rolling(21).std()

# %%
display(volatility.plot(figsize = (20,10),grid = True))

# %%
volatility.tail(2)
# Out:
# ticker      NSE/AXISBANK  NSE/ICICIBANK  NSE/SBIN
# Date
# 2018-02-22      0.016514       0.017604  0.023865
# 2018-02-23      0.016400       0.016244  0.022160

# %%
volatility.mean()
# Out:
# ticker
# NSE/AXISBANK     0.018787
# NSE/ICICIBANK    0.019545
# NSE/SBIN         0.020067
# dtype: float64

# %%
plt.figure(figsize = (10,10))
plt.scatter(pct_change.mean(), pct_change.std())

for label, x, y in zip(pct_change.columns, pct_change.mean(), pct_change.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (40, 10),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=0.5'))
    
plt.show()

# %%
correlation = pct_change.corr()

# %%
correlation
# Out:
# ticker         NSE/AXISBANK  NSE/ICICIBANK  NSE/SBIN
# ticker
# NSE/AXISBANK       1.000000       0.552289  0.463472
# NSE/ICICIBANK      0.552289       1.000000  0.657740
# NSE/SBIN           0.463472       0.657740  1.000000

# %%
plt.imshow(correlation, cmap = 'hot')
plt.colorbar()
plt.xticks(range(len(correlation)), correlation.columns, rotation = 45)
plt.yticks(range(len(correlation)), correlation.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x21e01126d68>,
#   <matplotlib.axis.YTick at 0x21e79285fd0>,
#   <matplotlib.axis.YTick at 0x21e01110be0>],
#  <a list of 3 Text yticklabel objects>)
